# %%
import math

import numpy as np

# %%
A = np.array([[0, 2], [1, 1], [-2, 0]], dtype=float)

# %%
A.T @ A
# Out:
# array([[5., 1.],
#        [1., 5.]])

# %%
np.linalg.eigvals(A.T @ A)
# Out:
# array([6., 4.])

# %%
Sigma = np.array([[math.sqrt(6), 0], [0, 2]])
Sigma
# Out:
# array([[2.44948974, 0.        ],
#        [0.        , 2.        ]])

# %%
np.linalg.eie

# %%
U, s, V = np.linalg.svd(A)

# %%
U
# Out:
# array([[-5.77350269e-01,  7.07106781e-01, -4.08248290e-01],
#        [-5.77350269e-01, -1.43931301e-16,  8.16496581e-01],
#        [ 5.77350269e-01,  7.07106781e-01,  4.08248290e-01]])

# %%
s
# Out:
# array([2.44948974, 2.        ])

# %%
V
# Out:
# array([[-0.70710678, -0.70710678],
#        [-0.70710678,  0.70710678]])

# %%
2.44948974 ** 2
# Out:
# 5.999999986365268
